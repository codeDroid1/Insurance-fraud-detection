# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
ls
# Out:
# EDA_fraudDetection.ipynb  Fraud_DetectionNotebook.ipynb  insuranceFraud.csv

# %%
data = pd.read_csv('insuranceFraud.csv')

# %%
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %%
data.shape
# Out:
# (1000, 39)

# %% [markdown]
# #### Correct Data Format

# %%
# Replace "?" values with NAN for imputer
data = data.replace('?', np.nan)

# %% [markdown]
# #### Drop Uselesss Columns

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
dropable_columns = ['policy_number','policy_bind_date','policy_state','insured_zip','incident_location','incident_date','incident_state','incident_city','insured_hobbies','auto_make','auto_model','auto_year']

# %%
data.drop(dropable_columns,1,inplace=True)

# %%
data.shape
# Out:
# (1000, 27)

# %% [markdown]
# #### Check Null values and Replace by Mode

# %%
data.isnull().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# fraud_reported                   0
# dtype: int64

# %%
data.describe()
# Out:
#        months_as_customer          age  policy_deductable  \
# count         1000.000000  1000.000000        1000.000000
# mean           203.954000    38.948000        1136.000000
# std            115.113174     9.140287         611.864673
# min              0.000000    19.000000         500.000000
# 25%            115.750000    32.000000         500.000000
# 50%            199.500000    38.000000        1000.000000
# 75%            276.250000    44.000000        2000.000000
# max            479.000000    64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06   25126.100000  -26793.700000
# std               244.167395    2.297407e+06   27872.187708   28104.096686
# min               433.330000   -1.000000e+06       0.000000 -111100.000000
# 25%              1089.607500    0.000000e+00       0.000000  -51500.000000
# 50%              1257.200000    0.000000e+00       0.000000  -23250.000000
# 75%              1415.695000    0.000000e+00   51025.000000       0.000000
# max              2047.590000    1.000000e+07  100500.000000       0.000000
#
#        incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# count               1000.000000                   1000.00000      1000.000000
# mean                  11.644000                      1.83900         0.992000
# std                    6.951373                      1.01888         0.820127
# min                    0.000000                      1.00000         0.000000
# 25%                    6.000000                      1.00000         0.000000
# 50%                   12.000000                      1.00000         1.000000
# 75%                   17.000000                      3.00000         2.000000
# max                   23.000000                      4.00000         2.000000
#
#          witnesses  total_claim_amount  injury_claim  property_claim  \
# count  1000.000000          1000.00000   1000.000000     1000.000000
# mean      1.487000         52761.94000   7433.420000     7399.570000
# std       1.111335         26401.53319   4880.951853     4824.726179
# min       0.000000           100.00000      0.000000        0.000000
# 25%       1.000000         41812.50000   4295.000000     4445.000000
# 50%       1.000000         58055.00000   6775.000000     6750.000000
# 75%       2.000000         70592.50000  11305.000000    10885.000000
# max       3.000000        114920.00000  21450.000000    23670.000000
#
#        vehicle_claim
# count    1000.000000
# mean    37928.950000
# std     18886.252893
# min        70.000000
# 25%     30292.500000
# 50%     42100.000000
# 75%     50822.500000
# max     79560.000000

# %%
data_mode = dict(data.mode().iloc[0])

# %%
data = data.fillna(data_mode)

# %% [markdown]
# #### Label Encoder and OneHotEncoder

# %%
cat_df = data.select_dtypes(include=['object']).copy()

# %%
num_df = data.select_dtypes(include=["int64"]).copy()

# %%
cat_df.head()
# Out:
#   policy_csl insured_sex insured_education_level insured_occupation  \
# 0    250/500        MALE                      MD       craft-repair
# 1    250/500        MALE                      MD  machine-op-inspct
# 2    100/300      FEMALE                     PhD              sales
# 3    250/500      FEMALE                     PhD       armed-forces
# 4   500/1000        MALE               Associate              sales
#
#   insured_relationship             incident_type   collision_type  \
# 0              husband  Single Vehicle Collision   Side Collision
# 1       other-relative             Vehicle Theft   Rear Collision
# 2            own-child   Multi-vehicle Collision   Rear Collision
# 3            unmarried  Single Vehicle Collision  Front Collision
# 4            unmarried             Vehicle Theft   Rear Collision
#
#   incident_severity authorities_contacted property_damage  \
# 0      Major Damage                Police             YES
# 1      Minor Damage                Police              NO
# 2      Minor Damage                Police              NO
# 3      Major Damage                Police              NO
# 4      Minor Damage                  None              NO
#
#   police_report_available fraud_reported
# 0                     YES              Y
# 1                      NO              Y
# 2                      NO              N
# 3                      NO              Y
# 4                      NO              N

# %%
list(cat_df.columns)
# Out:
# ['policy_csl',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_relationship',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'property_damage',
#  'police_report_available',
#  'fraud_reported']

# %%
for column in cat_df.columns:
    le = LabelEncoder()
    cat_df[column] = le.fit_transform(cat_df[column])

# %%
cat_df.head()
# Out:
#    policy_csl  insured_sex  insured_education_level  insured_occupation  \
# 0           1            1                        4                   2
# 1           1            1                        4                   6
# 2           0            0                        6                  11
# 3           1            0                        6                   1
# 4           2            1                        0                  11
#
#    insured_relationship  incident_type  collision_type  incident_severity  \
# 0                     0              2               2                  0
# 1                     2              3               1                  1
# 2                     3              0               1                  1
# 3                     4              2               0                  0
# 4                     4              3               1                  1
#
#    authorities_contacted  property_damage  police_report_available  \
# 0                      4                1                        1
# 1                      4                0                        0
# 2                      4                0                        0
# 3                      4                0                        0
# 4                      2                0                        0
#
#    fraud_reported
# 0               1
# 1               1
# 2               0
# 3               1
# 4               0

# %%
num_df.head()
# Out:
#    months_as_customer  age  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328   48               1000               0          53300
# 1                 228   42               2000         5000000              0
# 2                 134   29               2000         5000000          35100
# 3                 256   41               2000         6000000          48900
# 4                 228   44               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 0                1          2               71610          6510
# 1                0          0                5070           780
# 2                2          3               34650          7700
# 3                1          2               63400          6340
# 4                0          1                6500          1300
#
#    property_claim  vehicle_claim
# 0           13020          52080
# 1             780           3510
# 2            3850          23100
# 3            6340          50720
# 4             650           4550

# %%
final_df = pd.concat([num_df,cat_df], axis=1)

# %%
final_df.head()
# Out:
#    months_as_customer  age  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328   48               1000               0          53300
# 1                 228   42               2000         5000000              0
# 2                 134   29               2000         5000000          35100
# 3                 256   41               2000         6000000          48900
# 4                 228   44               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  ...  insured_education_level  \
# 0                1          2  ...                        4
# 1                0          0  ...                        4
# 2                2          3  ...                        6
# 3                1          2  ...                        6
# 4                0          1  ...                        0
#
#    insured_occupation  insured_relationship  incident_type  collision_type  \
# 0                   2                     0              2               2
# 1                   6                     2              3               1
# 2                  11                     3              0               1
# 3                   1                     4              2               0
# 4                  11                     4              3               1
#
#    incident_severity  authorities_contacted  property_damage  \
# 0                  0                      4                1
# 1                  1                      4                0
# 2                  1                      4                0
# 3                  0                      4                0
# 4                  1                      2                0
#
#    police_report_available  fraud_reported
# 0                        1               1
# 1                        0               1
# 2                        0               0
# 3                        0               1
# 4                        0               0
#
# [5 rows x 26 columns]

# %%
target_value = 'fraud_reported'
X = final_df.drop([target_value],1)
y = final_df[target_value]

# %% [markdown]
# #### Graph Plotting

# %% [markdown]
# #### Split data into train and test

# %%
train_X, test_X , train_y, test_y = train_test_split(X, y, test_size =0.3, random_state = 2020)

# %% [markdown]
# #### Train The Model

# %% [markdown]
# ##### RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=100)

# %%
pred_y = clf.fit(train_X, train_y).predict(test_X)

# %%
accuracy_score(test_y, pred_y)
# Out:
# 0.7566666666666667

# %%
confusion_matrix(test_y, pred_y)
# Out:
# array([[199,  29],
#        [ 44,  28]])

# %% [markdown]
# #### Support Vector Classifier

# %%
clf2 = SVC()

# %%
pred2_y = clf2.fit(train_X, train_y).predict(test_X)

# %%
accuracy_score(test_y, pred2_y)
# Out:
# 0.76

# %%
confusion_matrix(test_y, pred2_y)
# Out:
# array([[228,   0],
#        [ 72,   0]])

# %% [markdown]
# ##### GridSearchCv For Better Accuracy

# %%
param_grid = {"kernel": ['rbf','sigmoid'],
             "C":[0.1,0.5,1.0],
             "random_state":[0,10,20,30]}

# %%
grid = GridSearchCV(estimator=clf2, param_grid=param_grid, cv=5,  verbose=3)

# %%
grid.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] C=0.1, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.1, kernel=rbf, random_state=0, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.1, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.1, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.1, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=0 ...............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ... C=0.1, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.1, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.1, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.1, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.1, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.1, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.1, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=20, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=20, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=20, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.1, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=30, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=30, score=0.750, total=   0.1s
# [CV] C=0.1, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.1, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.5, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.5, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.5, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.5, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=0 ...............................
# [CV] ... C=0.5, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=10 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=20 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=rbf, random_state=30 ..............................
# [CV] .. C=0.5, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.5, kernel=sigmoid, random_state=0, score=0.743, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.5, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.5, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.5, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=0.5, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=10, score=0.743, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=20, score=0.743, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=30, score=0.743, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=0.5, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=0.5, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=0 ...............................
# [CV] ... C=1.0, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=0 ...............................
# [CV] ... C=1.0, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=0 ...............................
# [CV] ... C=1.0, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=0 ...............................
# [CV] ... C=1.0, kernel=rbf, random_state=0, score=0.750, total=   0.1s
# [CV] C=1.0, kernel=rbf, random_state=0 ...............................
# [CV] ... C=1.0, kernel=rbf, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=10 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=10 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=10 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=10 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=10 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=20 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=20 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=20 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=20 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=20, score=0.750, total=   0.1s
# [CV] C=1.0, kernel=rbf, random_state=20 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=30 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=30 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=30 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=30 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=rbf, random_state=30 ..............................
# [CV] .. C=1.0, kernel=rbf, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=1.0, kernel=sigmoid, random_state=0, score=0.743, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=1.0, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=1.0, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=1.0, kernel=sigmoid, random_state=0, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=0 ...........................
# [CV]  C=1.0, kernel=sigmoid, random_state=0, score=0.757, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=10, score=0.743, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=10, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=10 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=10, score=0.757, total=   0.1s
# [CV] C=1.0, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=20, score=0.743, total=   0.1s
# [CV] C=1.0, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=20, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=20 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=20, score=0.757, total=   0.1s
# [CV] C=1.0, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=30, score=0.743, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=30, score=0.750, total=   0.1s
# [CV] C=1.0, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=30, score=0.750, total=   0.0s
# [CV] C=1.0, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=30, score=0.750, total=   0.1s
# [CV] C=1.0, kernel=sigmoid, random_state=30 ..........................
# [CV]  C=1.0, kernel=sigmoid, random_state=30, score=0.757, total=   0.0s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:    5.8s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 0.5, 1.0], 'kernel': ['rbf', 'sigmoid'],
#                          'random_state': [0, 10, 20, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)
